# %%
# Load needed libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Turning off the warning in the model
pd.options.mode.chained_assignment=None

# %%
# Loading and reading the dataset
housing_df = pd.read_csv('USA_Housing.csv')

# %%
# Shape of the data
print('Number of rows = ',housing_df.shape[0])
print('Number of columns = ',housing_df.shape[1])
# Out:
# Number of rows =  5000
# Number of columns =  7

# %%
# Viewing the whole dataset
housing_df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
# Info of the dataset
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
# Describe 
housing_df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
# Columns in the dataset
housing_df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis

# %%
sns.set_palette('GnBu_r')

# %%
# Pairplot
sns.pairplot(housing_df)

# %%
# Heat Map
sns.heatmap(housing_df.corr(), annot=True, cmap='coolwarm')

# %%
# Regression plot
sns.lmplot(x='Avg. Area Income', y='Price', data=housing_df)

# %%
# Regression plot
sns.lmplot(x='Avg. Area House Age', y='Price', data=housing_df)

# %%
# Regression plot
sns.lmplot(x='Avg. Area Number of Rooms', y='Price', data=housing_df)

# %%
# Regression plot
sns.lmplot(x='Avg. Area Number of Bedrooms', y='Price', data=housing_df)

# %%
# Regression plot
sns.lmplot(x='Area Population', y='Price', data=housing_df)

# %%
# Split the columns into X and y
X = housing_df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population']]
y = housing_df['Price']

# %%
# Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
# Create and train model
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Coefficient of the model
print('Coefficient = ',model.coef_)
# Out:
# Coefficient =  [2.16176350e+01 1.65221120e+05 1.21405377e+05 1.31871878e+03
#  1.52251955e+01]

# %%
# Prediction of the model
predictions = model.predict(X_test)

# %%
# Scatterplot to compare the predicted_y and tested_y
plt.scatter(y_test, predictions)
plt.xlabel('Tested Y')
plt.ylabel('Predicted y')
# Out:
# Text(0, 0.5, 'Predicted y')

# %%
# Regression Metric Library
from sklearn import metrics

# Mean Absolute Error
print('MAE = ',metrics.mean_absolute_error(y_test, predictions))

# Mean Squared Error
print('MSE = ',metrics.mean_squared_error(y_test, predictions))

# Root Mean Squared Error
print('RMSE = ',np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE =  81257.55795855928
# MSE =  10169125565.897568
# RMSE =  100842.0823163503

# %%
# Variance Score
print('Variance Score = ',metrics.explained_variance_score(y_test, predictions))
# Out:
# Variance Score =  0.9185822770965283

# %%
# Residual Distplot
sns.distplot(y_test-predictions, bins=50)

# %%
# CDF
cdf = pd.DataFrame(model.coef_, X.columns, columns=['Coeff'])
cdf
# Out:
#                                       Coeff
# Avg. Area Income                  21.617635
# Avg. Area House Age           165221.119872
# Avg. Area Number of Rooms     121405.376596
# Avg. Area Number of Bedrooms    1318.718783
# Area Population                   15.225196
