# %%
# Importing the needed libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Turning off warning message
pd.options.mode.chained_assignment=None

# %%
# Reading the csv dataset file
customers_df = pd.read_csv('Ecommerce Customers.csv')

# %%
# Checking the shape of the whole data
print('Number of rows:: ',customers_df.shape[0])
print('Number of columns:: ',customers_df.shape[1])
# Out:
# Number of rows::  500
# Number of columns::  8

# %%
# Checking the whole data
customers_df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
# Checking the head() of the data
customers_df.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
# Checking the info() of the data
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
# Checking the describe() of the data
customers_df.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
# Check column names
customers_df.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis

# %%
sns.set_palette('GnBu_r')

# %%
# Joint plot to compare Time on Website and Yearly Amount Spent
sns.jointplot(x='Time on Website', y='Yearly Amount Spent', data=customers_df)

# %%
# Joint plot to compare Time on App and Yearly Amount Spent
sns.jointplot(x='Time on App', y='Yearly Amount Spent', data=customers_df)

# %%
# Joint plot to compare Time on App and Length of Membership
sns.jointplot(x='Time on App', y='Length of Membership', data=customers_df, kind='hex')

# %%
# Joint plot to compare Time on Website and Length of Membership
sns.jointplot(x='Time on Website', y='Length of Membership', data=customers_df, kind='hex')

# %%
# Pairplot
sns.pairplot(customers_df)

# %%
# Heat Map
sns.heatmap(customers_df.corr(), annot=True, cmap='coolwarm')

# %%
# Lm plot
sns.lmplot(x='Length of Membership', y='Yearly Amount Spent', data=customers_df)

# %%
# Spliting the data into training and test set
X = customers_df[['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership']]
y = customers_df['Yearly Amount Spent']

# %%
# Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
# Creating and training the model
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Printing the coefficients of the model
print('Coefficients: \n',model.coef_)
# Out:
# Coefficients:
#  [25.98154972 38.59015875  0.19040528 61.27909654]

# %%
# Prediction
predictions = model.predict(X_test)

# %%
# Scatterplot of real test values and predicted values
plt.scatter(y_test, predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
# Loading regression metrics library
from sklearn import metrics

# Mean Absolute Error
print('MAE = ', metrics.mean_absolute_error(y_test, predictions))

# Mean Squared Error
print('MSE = ', metrics.mean_squared_error(y_test, predictions))

# Root Mean Squared Error
print('RMSE = ', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE =  7.22814865343083
# MSE =  79.81305165097461
# RMSE =  8.933815066978642

# %%
# Explain variance score
print('Variance Score = ', metrics.explained_variance_score(y_test, predictions))
# Out:
# Variance Score =  0.9890771231889607

# %%
# Exploring the residual
sns.distplot((y_test-predictions), bins=50)

# %%
# How to boost the yearly amount spent by the customers
cdf = pd.DataFrame(model.coef_, X.columns, columns=['Coeff'])
cdf
# Out:
#                           Coeff
# Avg. Session Length   25.981550
# Time on App           38.590159
# Time on Website        0.190405
# Length of Membership  61.279097
