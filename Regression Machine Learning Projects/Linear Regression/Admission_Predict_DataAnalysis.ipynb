# %%
# Import the needed libraries
import numpy as np
import pandas as pd

# Turning off all possible warning
import warnings
warnings.filterwarnings('ignore')
pd.options.mode.chained_assignment=None

# Import the visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Read the dataset(csv)
Adpred_df = pd.read_csv('Admission_Predict.csv')

# %%
# Shape of the data
print('Number of rows: ',Adpred_df.shape[0])
print('Number of columns: ',Adpred_df.shape[1])
# Out:
# Number of rows:  400
# Number of columns:  9

# %%
# Checking the head and tail of the data
Adpred_df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
# Info of the data
Adpred_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
# Describe
Adpred_df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
# Checking for missing columns
Adpred_df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
# Checking for missing columns
Adpred_df.isna().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
# Columns of the data
Adpred_df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis

# %%
sns.set_palette('GnBu_r')
sns.set_style('whitegrid')

# %%
# Visualizing for any missing values
sns.heatmap(Adpred_df.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
# Pair Plot
sns.pairplot(Adpred_df)

# %%
# Heat Map
sns.heatmap(Adpred_df.corr(), annot=True, cmap='coolwarm')

# %%
# Joint Plot of GRE Score and TOEFL Score
sns.jointplot(x='GRE Score', y='TOEFL Score', data=Adpred_df)

# %%
# Joint Plot of GRE Score and CGPA
sns.jointplot(x='GRE Score', y='CGPA', data=Adpred_df)

# %%
# Joint Plot of GRE Score and Chance of Admit
sns.jointplot(x='GRE Score', y='Chance of Admit ', data=Adpred_df)

# %%
# Joint Plot of TOEFL Score and CGPA
sns.jointplot(x='TOEFL Score', y='CGPA', data=Adpred_df)

# %%
# Joint Plot of TOEFL Score and Chance of Admit
sns.jointplot(x='TOEFL Score', y='Chance of Admit ', data=Adpred_df)

# %%
# Joint Plot of CGPA and Chance of Admit
sns.jointplot(x='CGPA', y='Chance of Admit ', data=Adpred_df)

# %%
# Lm Plot of GRE Score and Chance of Admit
sns.lmplot(x='GRE Score', y='Chance of Admit ', data=Adpred_df)

# %%
# Lm Plot of TOEFL Score and Chance of Admit
sns.lmplot(x='TOEFL Score', y='Chance of Admit ', data=Adpred_df)

# %%
# Lm Plot of CGPA and Chance of Admit
sns.lmplot(x='CGPA', y='Chance of Admit ', data=Adpred_df)

# %%
# Split the columns into X and y
X = Adpred_df[['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA', 'Research']]
y = Adpred_df['Chance of Admit ']

# %%
# Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %%
# Create and train model(linear regression)
from sklearn.linear_model import LinearRegression
model1 = LinearRegression()
model1.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Coefficient of the data
print('Coefficient: \n',model1.coef_)
# Out:
# Coefficient:
#  [ 0.0023917   0.00291882  0.01136971 -0.0007102   0.01862304  0.10944958
#   0.00903536]

# %%
# Prediction
pred1 = model1.predict(X_test)

# %%
# ScatterPlot of the y_test(real test value) and pred1(predicted value)
plt.scatter(y_test, pred1)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
# Evaluating with regression metrics libraries
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score

# Mean Absolute Error
print('MAE = ', mean_absolute_error(y_test, pred1))

# Mean Squared Error
print('MSE = ', mean_squared_error(y_test, pred1))

# Root Mean Squared Error
print('RMSE = ', np.sqrt(mean_squared_error(y_test, pred1)))

print('\n')

# Explain variance score
print('Variance Score = ', explained_variance_score(y_test, pred1))
# Out:
# MAE =  0.047599393091849594
# MSE =  0.004801709701318092
# RMSE =  0.06929436991067955
#
#
# Variance Score =  0.7396074066076284

# %%
# Residual Distplot
sns.distplot((y_test-pred1), bins=50)

# %%
# CDF
cdf = pd.DataFrame(model1.coef_, X.columns, columns=['Coeff'])
cdf
# Out:
#                       Coeff
# GRE Score          0.002392
# TOEFL Score        0.002919
# University Rating  0.011370
# SOP               -0.000710
# LOR                0.018623
# CGPA               0.109450
# Research           0.009035
