# %%
# Load needed libraries
import numpy as np
import pandas as pd

# %%
# Warning turn off
import warnings
warnings.filterwarnings('ignore')
pd.options.mode.chained_assignment=None

# %%
# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Read csv
college_df = pd.read_csv('College_Data.csv')

# %%
# Shape of the data
print('Number of rows: ',college_df.shape[0])
print('Number of columns: ',college_df.shape[1])
# Out:
# Number of rows:  777
# Number of columns:  18

# %%
# Head and tail of the data
college_df
# Out:
#     private   apps  accept  enroll  top10perc  top25perc  f_undergrad  \
# 0       Yes   1660    1232     721         23         52         2885
# 1       Yes   2186    1924     512         16         29         2683
# 2       Yes   1428    1097     336         22         50         1036
# 3       Yes    417     349     137         60         89          510
# 4       Yes    193     146      55         16         44          249
# ..      ...    ...     ...     ...        ...        ...          ...
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# 774     Yes   2097    1915     695         34         61         2793
# 775     Yes  10705    2453    1317         95         99         5217
# 776     Yes   2989    1855     691         28         63         2988
#
#      p_undergrad  outstate  room_board  books  personal  phd  terminal  \
# ...

# %%
# Info
college_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   private      777 non-null    object
#  1   apps         777 non-null    int64
#  2   accept       777 non-null    int64
#  3   enroll       777 non-null    int64
#  4   top10perc    777 non-null    int64
#  5   top25perc    777 non-null    int64
#  6   f_undergrad  777 non-null    int64
#  7   p_undergrad  777 non-null    int64
#  8   outstate     777 non-null    int64
#  9   room_board   777 non-null    int64
#  10  books        777 non-null    int64
#  11  personal     777 non-null    int64
#  12  phd          777 non-null    int64
#  13  terminal     777 non-null    int64
#  14  s_f_ratio    777 non-null    float64
#  15  perc_alumni  777 non-null    int64
#  16  expend       777 non-null    int64
#  17  grad_rate    777 non-null    int64
# dtypes: float64(1), int64(16), object(1)
# ...

# %%
# Describe
college_df.describe()
# Out:
#                apps        accept       enroll   top10perc   top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         f_undergrad   p_undergrad      outstate   room_board        books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
# Checking for missing columns
college_df.isnull().sum()
# Out:
# private        0
# apps           0
# accept         0
# enroll         0
# top10perc      0
# top25perc      0
# f_undergrad    0
# p_undergrad    0
# outstate       0
# room_board     0
# books          0
# personal       0
# phd            0
# terminal       0
# s_f_ratio      0
# perc_alumni    0
# expend         0
# grad_rate      0
# dtype: int64

# %%
# Columns
college_df.columns
# Out:
# Index(['private', 'apps', 'accept', 'enroll', 'top10perc', 'top25perc',
#        'f_undergrad', 'p_undergrad', 'outstate', 'room_board', 'books',
#        'personal', 'phd', 'terminal', 's_f_ratio', 'perc_alumni', 'expend',
#        'grad_rate'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis

# %%
sns.set_palette('GnBu_r')
sns.set_style('whitegrid')

# %%
# Scatter Plot of room_board vs grad_rate
sns.lmplot(x='room_board', y='grad_rate', data=college_df, hue='private', fit_reg=False, palette='coolwarm', size=6, aspect=1)

# %%
# Scatter Plot of f_undergrad vs outstate
sns.lmplot(x='outstate',y='f_undergrad', data=college_df, hue='private', fit_reg=False, palette='coolwarm', size=6, aspect=1)

# %%
# Histogram for outstate
g = sns.FacetGrid(data=college_df, hue='private', palette='coolwarm', size=6, aspect=2)
g = g.map(plt.hist, 'outstate', bins=20, alpha=0.7)

# %%
# Histogram for grad_rate
h = sns.FacetGrid(data=college_df, hue='private', palette='coolwarm', size=6, aspect=2)
h = h.map(plt.hist, 'grad_rate', bins=20, alpha=0.7)

# %%
# Create and train model
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2)
kmeans.fit(college_df.drop('private',axis=1))
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
# Cluster center vector
kmeans.cluster_centers_
# Out:
# array([[1.81323468e+03, 1.28716592e+03, 4.91044843e+02, 2.53094170e+01,
#         5.34708520e+01, 2.18854858e+03, 5.95458894e+02, 1.03957085e+04,
#         4.31136472e+03, 5.41982063e+02, 1.28033632e+03, 7.04424514e+01,
#         7.78251121e+01, 1.40997010e+01, 2.31748879e+01, 8.93204634e+03,
#         6.51195815e+01],
#        [1.03631389e+04, 6.55089815e+03, 2.56972222e+03, 4.14907407e+01,
#         7.02037037e+01, 1.30619352e+04, 2.46486111e+03, 1.07191759e+04,
#         4.64347222e+03, 5.95212963e+02, 1.71420370e+03, 8.63981481e+01,
#         9.13333333e+01, 1.40277778e+01, 2.00740741e+01, 1.41705000e+04,
#         6.75925926e+01]])

# %%
# Function to convert 'private' column to what machine can read
def converter(private):
    if private == 'Yes':
        return 1
    else:
        return 0

# %%
# Creating a new column 'Cluster'
college_df['Cluster'] = college_df['private'].apply(converter)

# %%
# Head and tail of the data showing the newly added 'Cluster' column
college_df
# Out:
#     private   apps  accept  enroll  top10perc  top25perc  f_undergrad  \
# 0       Yes   1660    1232     721         23         52         2885
# 1       Yes   2186    1924     512         16         29         2683
# 2       Yes   1428    1097     336         22         50         1036
# 3       Yes    417     349     137         60         89          510
# 4       Yes    193     146      55         16         44          249
# ..      ...    ...     ...     ...        ...        ...          ...
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# 774     Yes   2097    1915     695         34         61         2793
# 775     Yes  10705    2453    1317         95         99         5217
# 776     Yes   2989    1855     691         28         63         2988
#
#      p_undergrad  outstate  room_board  books  personal  phd  terminal  \
# ...

# %%
# Checking the confusion matrix and classification report of the kmeans cluster
from sklearn.metrics import confusion_matrix, classification_report

# Confusion Matrix
print(confusion_matrix(college_df['Cluster'], kmeans.labels_))
print('\n')

# Classification Report
print(classification_report(college_df['Cluster'], kmeans.labels_))
# Out:
# [[138  74]
#  [531  34]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.21      0.65      0.31       212
#            1       0.31      0.06      0.10       565
#
#     accuracy                           0.22       777
#    macro avg       0.26      0.36      0.21       777
# weighted avg       0.29      0.22      0.16       777
